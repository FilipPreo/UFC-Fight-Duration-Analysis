# %%
import pandas as pd
ufc = pd.read_csv('data.csv')
meta = pd.read_csv('raw_total_fight_data.csv', sep=';')
ufc.info
# Out:
# <bound method DataFrame.info of                  R_fighter       B_fighter               Referee        date  \
# 0             Henry Cejudo   Marlon Moraes          Marc Goddard  2019-06-08
# 1     Valentina Shevchenko     Jessica Eye       Robert Madrigal  2019-06-08
# 2            Tony Ferguson  Donald Cerrone       Dan Miragliotta  2019-06-08
# 3            Jimmie Rivera        Petr Yan       Kevin MacDonald  2019-06-08
# 4              Tai Tuivasa   Blagoy Ivanov       Dan Miragliotta  2019-06-08
# ...                    ...             ...                   ...         ...
# 5139        Gerard Gordeau    Kevin Rosier  Joao Alberto Barreto  1993-11-12
# 5140          Ken Shamrock   Patrick Smith  Joao Alberto Barreto  1993-11-12
# 5141          Royce Gracie   Art Jimmerson  Joao Alberto Barreto  1993-11-12
# 5142          Kevin Rosier    Zane Frazier  Joao Alberto Barreto  1993-11-12
# 5143        Gerard Gordeau      Teila Tuli  Joao Alberto Barreto  1993-11-12
#
# ...

# %%
ufc.head()
# Out:
#               R_fighter       B_fighter          Referee        date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal  2019-06-08
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  ...  R_win_by_KO/TKO  R_win_by_Submission  \
# ...

# %%
for i in ufc.columns:
    print(i)
# Out:
# R_fighter
# B_fighter
# Referee
# date
# location
# Winner
# title_bout
# weight_class
# no_of_rounds
# B_current_lose_streak
# B_current_win_streak
# B_draw
# B_avg_BODY_att
# B_avg_BODY_landed
# B_avg_CLINCH_att
# B_avg_CLINCH_landed
# B_avg_DISTANCE_att
# B_avg_DISTANCE_landed
# B_avg_GROUND_att
# B_avg_GROUND_landed
# B_avg_HEAD_att
# B_avg_HEAD_landed
# B_avg_KD
# B_avg_LEG_att
# B_avg_LEG_landed
# B_avg_PASS
# B_avg_REV
# B_avg_SIG_STR_att
# B_avg_SIG_STR_landed
# B_avg_SIG_STR_pct
# B_avg_SUB_ATT
# B_avg_TD_att
# B_avg_TD_landed
# B_avg_TD_pct
# B_avg_TOTAL_STR_att
# B_avg_TOTAL_STR_landed
# B_longest_win_streak
# B_losses
# B_avg_opp_BODY_att
# B_avg_opp_BODY_landed
# B_avg_opp_CLINCH_att
# B_avg_opp_CLINCH_landed
# B_avg_opp_DISTANCE_att
# B_avg_opp_DISTANCE_landed
# B_avg_opp_GROUND_att
# B_avg_opp_GROUND_landed
# B_avg_opp_HEAD_att
# B_avg_opp_HEAD_landed
# B_avg_opp_KD
# B_avg_opp_LEG_att
# B_avg_opp_LEG_landed
# B_avg_opp_PASS
# B_avg_opp_REV
# B_avg_opp_SIG_STR_att
# ...

# %%
meta.iloc[0]
# Out:
# R_fighter                         Henry Cejudo
# B_fighter                        Marlon Moraes
# R_KD                                         0
# B_KD                                         0
# R_SIG_STR.                           90 of 171
# B_SIG_STR.                           57 of 119
# R_SIG_STR_pct                              52%
# B_SIG_STR_pct                              47%
# R_TOTAL_STR.                         99 of 182
# B_TOTAL_STR.                         59 of 121
# R_TD                                    1 of 4
# B_TD                                    0 of 2
# R_TD_pct                                   25%
# B_TD_pct                                    0%
# R_SUB_ATT                                    1
# B_SUB_ATT                                    0
# R_PASS                                       1
# B_PASS                                       0
# R_REV                                        0
# B_REV                                        0
# ...

# %%
for i in meta.columns:
    print(i)
# Out:
# R_fighter
# B_fighter
# R_KD
# B_KD
# R_SIG_STR.
# B_SIG_STR.
# R_SIG_STR_pct
# B_SIG_STR_pct
# R_TOTAL_STR.
# B_TOTAL_STR.
# R_TD
# B_TD
# R_TD_pct
# B_TD_pct
# R_SUB_ATT
# B_SUB_ATT
# R_PASS
# B_PASS
# R_REV
# B_REV
# R_HEAD
# B_HEAD
# R_BODY
# B_BODY
# R_LEG
# B_LEG
# R_DISTANCE
# B_DISTANCE
# R_CLINCH
# B_CLINCH
# R_GROUND
# B_GROUND
# win_by
# last_round
# last_round_time
# Format
# Referee
# date
# location
# Fight_type
# Winner

# %%
meta.head()
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR. B_SIG_STR.  \
# 0          Henry Cejudo   Marlon Moraes     0     0   90 of 171  57 of 119
# 1  Valentina Shevchenko     Jessica Eye     1     0     8 of 11    2 of 12
# 2         Tony Ferguson  Donald Cerrone     0     0  104 of 200  68 of 185
# 3         Jimmie Rivera        Petr Yan     0     2   73 of 192  56 of 189
# 4           Tai Tuivasa   Blagoy Ivanov     0     1   64 of 144  73 of 123
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  ... B_GROUND  \
# 0           52%           47%    99 of 182    59 of 121  ...   1 of 1
# 1           72%           16%     37 of 40     42 of 52  ...   0 of 0
# 2           52%           36%   104 of 200    68 of 185  ...   0 of 0
# 3           38%           29%    76 of 195    58 of 192  ...  4 of 10
# 4           44%           59%    66 of 146    81 of 131  ...   6 of 6
#
#                     win_by last_round last_round_time             Format  \
# ...

# %%
time_data = pd.concat([meta['date'], meta['last_round'], meta['last_round_time']], axis=1)

# %%
time_data.head()
# Out:
#             date  last_round last_round_time
# 0  June 08, 2019           3            4:51
# 1  June 08, 2019           2            0:26
# 2  June 08, 2019           2            5:00
# 3  June 08, 2019           3            5:00
# 4  June 08, 2019           3            5:00

# %%
len(time_data)
# Out:
# 5144

# %%
len(ufc)
# Out:
# 5144

# %%
ufc.head()
# Out:
#               R_fighter       B_fighter          Referee        date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal  2019-06-08
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  ...  R_win_by_KO/TKO  R_win_by_Submission  \
# ...

# %%
type(ufc.date[0])
# Out:
# str

# %%
ufc.date=pd.to_datetime(ufc.date, format='%Y/%m/%d')

# %%
time_data.date = pd.to_datetime(time_data.date, format='%B %d, %Y')

# %%
time_data.head()
# Out:
#             last_round last_round_time
# date
# 2019-06-08           3            4:51
# 2019-06-08           2            0:26
# 2019-06-08           2            5:00
# 2019-06-08           3            5:00
# 2019-06-08           3            5:00

# %%
type(time_data.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
time_data.head()
# Out:
#             last_round last_round_time
# date
# 2019-06-08           3            4:51
# 2019-06-08           2            0:26
# 2019-06-08           2            5:00
# 2019-06-08           3            5:00
# 2019-06-08           3            5:00

# %%
ufc.set_index(ufc.date, inplace=True, drop=True)

# %%
ufc.head()
# Out:
#                        R_fighter       B_fighter          Referee       date  \
# date
# 2019-06-08          Henry Cejudo   Marlon Moraes     Marc Goddard 2019-06-08
# 2019-06-08  Valentina Shevchenko     Jessica Eye  Robert Madrigal 2019-06-08
# 2019-06-08         Tony Ferguson  Donald Cerrone  Dan Miragliotta 2019-06-08
# 2019-06-08         Jimmie Rivera        Petr Yan  Kevin MacDonald 2019-06-08
# 2019-06-08           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta 2019-06-08
#
#                           location Winner  title_bout       weight_class  \
# date
# 2019-06-08  Chicago, Illinois, USA    Red        True       Bantamweight
# 2019-06-08  Chicago, Illinois, USA    Red        True  Women's Flyweight
# 2019-06-08  Chicago, Illinois, USA    Red       False        Lightweight
# 2019-06-08  Chicago, Illinois, USA   Blue       False       Bantamweight
# 2019-06-08  Chicago, Illinois, USA   Blue       False        Heavyweight
#
# ...

# %%
ufc_total = ufc.join(time_data)

# %%
ufc_total.head()
# Out:
#                R_fighter       B_fighter               Referee       date  \
# date
# 1993-11-12  Royce Gracie  Gerard Gordeau  Joao Alberto Barreto 1993-11-12
# 1993-11-12  Royce Gracie  Gerard Gordeau  Joao Alberto Barreto 1993-11-12
# 1993-11-12  Royce Gracie  Gerard Gordeau  Joao Alberto Barreto 1993-11-12
# 1993-11-12  Royce Gracie  Gerard Gordeau  Joao Alberto Barreto 1993-11-12
# 1993-11-12  Royce Gracie  Gerard Gordeau  Joao Alberto Barreto 1993-11-12
#
#                          location Winner  title_bout  weight_class  \
# date
# 1993-11-12  Denver, Colorado, USA    Red        True  Catch Weight
# 1993-11-12  Denver, Colorado, USA    Red        True  Catch Weight
# 1993-11-12  Denver, Colorado, USA    Red        True  Catch Weight
# 1993-11-12  Denver, Colorado, USA    Red        True  Catch Weight
# 1993-11-12  Denver, Colorado, USA    Red        True  Catch Weight
#
#             no_of_rounds  B_current_lose_streak  ...  \
# ...

# %%
ufc_total.drop(columns=['date'], inplace=True)

# %%
ufc_total.head()
# Out:
#                R_fighter       B_fighter               Referee  \
# date
# 1993-11-12  Royce Gracie  Gerard Gordeau  Joao Alberto Barreto
# 1993-11-12  Royce Gracie  Gerard Gordeau  Joao Alberto Barreto
# 1993-11-12  Royce Gracie  Gerard Gordeau  Joao Alberto Barreto
# 1993-11-12  Royce Gracie  Gerard Gordeau  Joao Alberto Barreto
# 1993-11-12  Royce Gracie  Gerard Gordeau  Joao Alberto Barreto
#
#                          location Winner  title_bout  weight_class  \
# date
# 1993-11-12  Denver, Colorado, USA    Red        True  Catch Weight
# 1993-11-12  Denver, Colorado, USA    Red        True  Catch Weight
# 1993-11-12  Denver, Colorado, USA    Red        True  Catch Weight
# 1993-11-12  Denver, Colorado, USA    Red        True  Catch Weight
# 1993-11-12  Denver, Colorado, USA    Red        True  Catch Weight
#
#             no_of_rounds  B_current_lose_streak  B_current_win_streak  ...  \
# date                                                                   ...
# ...

# %%
ufc_total['TIME'] = (ufc_total.last_round_time) + (ufc_total.last_round - 1)*pd.Timedelta(5, unit='m')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-7693631f6252> in <module>
# ----> 1 ufc_total['TIME'] = (ufc_total.last_round_time) + (ufc_total.last_round - 1)*pd.Timedelta(5, unit='m')
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#    1020             assert isinstance(right, (pd.TimedeltaIndex, ABCTimedeltaArray, ABCSeries))
#    1021             try:
# -> 1022                 result = op(left._values, right)
#    1023             except NullFrequencyError:
#    1024                 if orig_right is not right:
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     808         # for binary ops, use our custom dunder methods
#     809         result = ops.maybe_dispatch_ufunc_to_dunder_op(
# ...

# %%
for i in range(len(ufc_total)):
    ufc_total['TIME'][i] = ufc_total.last_round_time[i] + (ufc_total.last_round[i]  - 1)*pd.Timedelta(5, unit='m')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-64797bc1403e> in <module>
#       1 for i in range(len(ufc_total)):
# ----> 2     ufc_total['TIME'][i] = ufc_total.last_round_time[i] + (ufc_total.last_round[i] - 1)*pd.Timedelta(5, unit='m')
#
# TypeError: must be str, not numpy.timedelta64

# %%
ufc_total.last_round[3000] -1
# Out:
# 1

# %%
ufc_total['time_so_far'] = (ufc_total.last_round  - 1)*pd.Timedelta(5, unit='m')

# %%
ufc_total.tail()
# Out:
#                     R_fighter          B_fighter          Referee  \
# date
# 2019-06-08  Katlyn Chookagian  Joanne Calderwood  Dan Miragliotta
# 2019-06-08  Katlyn Chookagian  Joanne Calderwood  Dan Miragliotta
# 2019-06-08  Katlyn Chookagian  Joanne Calderwood  Dan Miragliotta
# 2019-06-08  Katlyn Chookagian  Joanne Calderwood  Dan Miragliotta
# 2019-06-08  Katlyn Chookagian  Joanne Calderwood  Dan Miragliotta
#
#                           location Winner  title_bout       weight_class  \
# date
# 2019-06-08  Chicago, Illinois, USA    Red       False  Women's Flyweight
# 2019-06-08  Chicago, Illinois, USA    Red       False  Women's Flyweight
# 2019-06-08  Chicago, Illinois, USA    Red       False  Women's Flyweight
# 2019-06-08  Chicago, Illinois, USA    Red       False  Women's Flyweight
# 2019-06-08  Chicago, Illinois, USA    Red       False  Women's Flyweight
#
#             no_of_rounds  B_current_lose_streak  B_current_win_streak  ...  \
# ...

# %%
ufc_total['TIME'] = (ufc_total.time_so_far) + (ufc_total.last_round_time)

# %%
type(ufc_total.time_so_far[0])
# Out:
# pandas._libs.tslibs.timedeltas.Timedelta

# %%
type(ufc_total.last_round_time[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
ufc_total.last_round_time = pd.to_datetime(ufc_total.last_round_time, format='%M:%S')

# %%
# Out:
#                     R_fighter          B_fighter               Referee  \
# date
# 1993-11-12       Royce Gracie     Gerard Gordeau  Joao Alberto Barreto
# 1993-11-12       Royce Gracie     Gerard Gordeau  Joao Alberto Barreto
# 1993-11-12       Royce Gracie     Gerard Gordeau  Joao Alberto Barreto
# 1993-11-12       Royce Gracie     Gerard Gordeau  Joao Alberto Barreto
# 1993-11-12       Royce Gracie     Gerard Gordeau  Joao Alberto Barreto
# ...                       ...                ...                   ...
# 2019-06-08  Katlyn Chookagian  Joanne Calderwood       Dan Miragliotta
# 2019-06-08  Katlyn Chookagian  Joanne Calderwood       Dan Miragliotta
# 2019-06-08  Katlyn Chookagian  Joanne Calderwood       Dan Miragliotta
# 2019-06-08  Katlyn Chookagian  Joanne Calderwood       Dan Miragliotta
# 2019-06-08  Katlyn Chookagian  Joanne Calderwood       Dan Miragliotta
#
#                           location Winner  title_bout       weight_class  \
# date
# ...
